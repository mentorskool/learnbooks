# %%
#@title 
# %%html
<marquee style='width: 100%; color: #00a7f4;font-size:30px;'><b>Welcome to Mentorskool!</b></marquee>
# Out:
# <marquee style='width: 100%; color: #00a7f4;font-size:30px;'><b>Welcome to Mentorskool!</b></marquee>

# %% [markdown]
# ### **Activity 1 :**
# -----------------
# **Connect to Mentorskool open Database**
#
# **Note :** *In case you wish to proceed with this mini lab, you'll need the database credentials. Just ping us on Slack to fetch the same.*
#
# Happy coding!

# %%
# Execute the below code if any of the two packages are not installed
# !pip install pyodbc
# ! pip install pymssql

# %%
# import pyodbc package
import pyodbc

# %%
# Write your code here

# %% [markdown]
# ### **Activity 2 :**
# -----------------
# **Read data from the table Trips**

# %%
# Write your code here

# %% [markdown]
# ### **Activity 3 :**
# -----------------
# **Insert a new record into the trips table**

# %%
# Write your code here
